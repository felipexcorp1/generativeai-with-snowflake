# %%
from snowflake.snowpark.context import get_active_session
import snowflake.snowpark.functions as F
import streamlit as st
import ast

session = get_active_session()

# %%
medical_notes = """Patient: John Smith
Age: 52
Date of Visit: August 26, 2026

Chief Complaint:
The patient presents with persistent lower back pain that started approximately three weeks ago. He describes the pain as a dull, aching sensation located primarily in the lumbar region. The pain is more noticeable after sitting for extended periods and tends to improve slightly with light movement.

History of Present Illness:
The patient reports that the symptoms began gradually without a specific injury or traumatic event. He works at a desk for approximately eight hours per day and reports limited physical activity during the work week. Over the past week, the pain has become more frequent and occasionally interferes with sleep. He rates the pain at approximately 6 out of 10 at its worst and 3 out of 10 at rest.

The patient denies recent falls, accidents, heavy lifting, or other significant trauma. He denies pain radiating below the knees. He also denies numbness, tingling, or weakness in either lower extremity. There is no reported loss of bowel or bladder control.

Past Medical History:
The patient has a history of hypertension diagnosed approximately six years ago. Blood pressure has generally been well controlled with medication. He also reports occasional tension headaches associated with periods of increased stress.

The patient has no known history of diabetes, cardiovascular disease, kidney disease, or previous spinal surgery.

Current Medications:
- Lisinopril 10 mg once daily for hypertension
- Acetaminophen as needed for occasional headaches or pain
- No other regular medications reported

Allergies:
No known drug allergies.

Family History:
The patient's father had hypertension and was diagnosed with coronary artery disease in his early sixties. His mother has a history of osteoarthritis. There is no known family history of inflammatory arthritis or neurological disorders.

Social History:
The patient works full-time in an office environment and spends most of his working day seated at a computer. He reports that he does not exercise regularly but occasionally goes for walks on weekends. He does not smoke cigarettes. He reports drinking alcohol socially, approximately one to two drinks per week.

Review of Systems:
Constitutional: No fever, chills, unexplained weight loss, or persistent fatigue.
Musculoskeletal: Persistent lower back pain and morning stiffness. No significant joint swelling.
Neurological: No weakness, numbness, tingling, dizziness, or changes in coordination.
Cardiovascular: No chest pain, palpitations, or shortness of breath.
Respiratory: No cough or difficulty breathing.
Gastrointestinal: No abdominal pain, nausea, vomiting, or changes in bowel habits.
Genitourinary: No urinary difficulty or changes in bladder control.

Physical Examination:
Patient is alert, oriented, and in no acute distress. Vital signs are stable. Mild tenderness is noted in the lower lumbar paraspinal muscles. Range of motion is mildly limited by discomfort, particularly during forward flexion. Lower extremity strength is normal and symmetric. Sensation is intact bilaterally. Deep tendon reflexes are normal. No obvious neurological deficits are identified.

Assessment:
The clinical presentation is most consistent with nonspecific mechanical lower back pain. There are currently no reported red-flag symptoms such as significant neurological deficits, bowel or bladder dysfunction, unexplained weight loss, fever, or recent major trauma.

Plan:
The patient was advised to remain physically active as tolerated and avoid prolonged periods of sitting. Gentle stretching and gradual strengthening exercises were discussed. The patient was advised to use appropriate ergonomic support while working at his desk.

Over-the-counter pain management may be considered according to the patient's usual tolerance and medical advice. The patient was advised to follow up with his primary care provider if symptoms persist, worsen, or begin to interfere significantly with daily activities.

If neurological symptoms develop, including new weakness, significant numbness, loss of bowel or bladder control, or severe worsening pain, the patient should seek prompt medical evaluation.

Follow-up:
Follow-up with the primary care provider is recommended in approximately two to four weeks, or sooner if symptoms worsen.
"""

# %%
import json

medical_request = [
    {'role': 'system', 'content': "Your goal is to extract structured information from the user's input that matches the form described below. When extracting information please make sure it matches the type information exactly, and provide the extrated information. \n Conditions: <complete conditions> \n Interventions:{complete interventions}"},
    {'role': 'user', 'content': medical_notes }
]
print(json.dumps(medical_request, indent=2))

# %%
import json
from snowflake.cortex import complete

response = complete("llama3.1-70b", medical_request)

try:
    structured = json.loads(response)
    print(json.dumps(structured, indent=2, ensure_ascii=False))
except (json.JSONDecodeError, TypeError):
    translated = complete("llama3.1-70b", f"Traduce el siguiente texto al español, mantén el formato exacto:\n\n{response}")
    print(translated)

# %%
import json
from snowflake.cortex import complete

response = complete("llama3.1-8b", medical_request)

try:
    structured = json.loads(response)
    print(json.dumps(structured, indent=2, ensure_ascii=False))
except (json.JSONDecodeError, TypeError):
    translated = complete("llama3.1-8b", f"Traduce el siguiente texto al español, mantén el formato exacto:\n\n{response}")
    print(translated)

# %%
from IPython.display import display, Markdown
from snowflake.cortex import complete

response = complete("openai-gpt-5-mini", medical_request)

display(Markdown(response.replace("\\n", "\n")))
